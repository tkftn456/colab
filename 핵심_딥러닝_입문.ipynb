# %% [markdown]
# <a href="https://colab.research.google.com/github/tkftn456/colab/blob/main/%ED%95%B5%EC%8B%AC_%EB%94%A5%EB%9F%AC%EB%8B%9D_%EC%9E%85%EB%AC%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 코랩 사용해보기

# %%
print('hello world')
# Out:
# hello world

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-np.pi, np.pi)
plt.plot(x, np.cos(x))
plt.plot(x, np.sin(x))
plt.show()
